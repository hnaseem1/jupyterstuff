# %%
import os
os.listdir()
# Out:
# ['NoMongoStartingNB.ipynb',
#  'Test2.ipynb',
#  'Copy of Javed Jutt.xlsx',
#  'TestFile1.ipynb',
#  '.ipynb_checkpoints']

# %%
import pandas

# %%
df1 = pandas.read_excel('Copy of Javed Jutt.xlsx', sheet_name=0)

# %%
print(df1)
# Out:
#      Code                                  Name  Javed Jutt Balance  \
# 0   465.0                           A.M Traders             32702.0
# 1   542.0      Adnan Siddique (Fateh Pur Kamal)             16566.0
# 2   448.0                      Alamgeer Traders                 0.0
# 3   558.0                    Al Rayan Marketing             37705.0
# 4   519.0                           Ali Traders             55560.0
# 5   449.0                           Ameen Sweet              6934.0
# 6   180.0                          Arif Traders              5000.0
# 7   467.0                        Arshad Traders             55626.0
# 8   439.0                         Asad Brothers             10662.0
# 9   195.0                       Ashraf Brothers             34026.0
# 10  268.0                          Atif Traders                 0.0
# 11  481.0                       Bahadur Traders                 0.0
# 12  251.0                        Bhatti Traders                 0.0
# ...
